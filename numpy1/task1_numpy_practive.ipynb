# %% [markdown]
# # ДЗ №1 СУНЦ МГУ - Numpy practice

# %% [markdown]
# _Задачи позаимствованы из курса ML ФКН ПМИ где они были позаимствованы из курса практикума кафедры ММП факультета ВМК МГУ_

# %% [markdown]
# ### Туториальные задачи
# __(9 баллов)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.5 балла__, векторизованная – в __1 балл__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py
#
# Для каждой задачи, приведённой ниже сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size ** 2 + 10
time_vectorized = data_size ** 1.5

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

ax1.plot(data_size, time_non_vectorized)
ax1.plot(data_size, time_vectorized)
ax1.set_title(u"Плохой график")
ax1.set_xlabel(u"Размер данных")
ax1.set_ylabel(u"Время")

ax2.plot(data_size, time_non_vectorized, label=u"Невекторизованная")
ax2.plot(data_size, time_vectorized, label=u"Векторизованная")
ax2.set_title(u"Хороший график")
ax2.set_xlabel(u"Длина массива")
ax2.set_ylabel(u"Время (с)")
ax2.grid()
ax2.legend()

f.show()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_22436\3107362156.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()

# %% [markdown]
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.

# %%
from random import randint as rnd
from time import time
import importlib
import numpy1.functions as functions
import functions_vectorized
from numpy1.functions import prod_non_zero_diag as fpy
from functions_vectorized import prod_non_zero_diag  as fvec
import numpy as np
import matplotlib.pyplot as plt

importlib.reload(functions)
importlib.reload(functions_vectorized)

data_size = [x for x in range(1000, 25001, 125)]

tvec = []
tpy = []

for n in data_size:
    v = np.random.randint(0, 1, size=(n, n))
    st = time()
    fpy(v)
    tpy.append(time() - st)
    st = time()
    fvec(v)
    tvec.append(time() - st)
plt.figure(figsize=(8, 6))

plt.plot(data_size, tpy, label=u"Невекторизованная")
plt.plot(data_size, tvec, label=u"Векторизованная")

plt.title(u"Сравнение времени выполнения алгоритмов")
plt.xlabel(u"Размер данных")
plt.ylabel(u"Время (с)")
plt.grid(True)
plt.legend()

# %% [markdown]
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.

# %%
from random import randint as rnd
from time import time
import importlib
import numpy1.functions as functions
import functions_vectorized
from numpy1.functions import are_multisets_equal as fpy
from functions_vectorized import are_multisets_equal  as fvec
import numpy as np
import matplotlib.pyplot as plt

importlib.reload(functions)
importlib.reload(functions_vectorized)

data_size = [x for x in range(10 ** 4, 10 ** 6 + 1, 10 ** 4)]

tvec = []
tpy = []

for n in data_size:
    x = np.random.randint(0, 10 ** 9, size=(n))
    st = time()
    fpy(x, x)
    tpy.append(time() - st)
    st = time()
    fvec(x, x)
    tvec.append(time() - st)

plt.figure(figsize=(8, 6))

plt.plot(data_size, tpy, label=u"Невекторизованная")
plt.plot(data_size, tvec, label=u"Векторизованная")

plt.title(u"Сравнение времени выполнения алгоритмов")
plt.xlabel(u"Размер данных")
plt.ylabel(u"Время (с)")
plt.grid(True)
plt.legend()

# %% [markdown]
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.

# %%
from random import randint as rnd
from time import time
import importlib
import numpy1.functions as functions
import functions_vectorized
from numpy1.functions import max_after_zero as fpy
from functions_vectorized import max_after_zero  as fvec
import numpy as np
import matplotlib.pyplot as plt

importlib.reload(functions)
importlib.reload(functions_vectorized)

data_size = [x for x in range(10 ** 4, 10 ** 6 + 1, 10 ** 4)]
tvec = []
tpy = []

for n in data_size:
    x = np.random.randint(0, 10 ** 9, size=(n)) * np.random.randint(0, 2, size=(n))
    x = np.append(x, 1)
    st = time()
    fpy(x)
    tpy.append(time() - st)
    st = time()
    fvec(x)
    tvec.append(time() - st)

plt.figure(figsize=(8, 6))

plt.plot(data_size, tpy, label=u"Невекторизованная")
plt.plot(data_size, tvec, label=u"Векторизованная")

plt.title(u"Сравнение времени выполнения алгоритмов")
plt.xlabel(u"Размер данных")
plt.ylabel(u"Время (с)")
plt.grid(True)
plt.legend()

# %% [markdown]
#
#
# * __ Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно при помощи функции scipy.misc.imread (если изображение не в формате png, установите пакет pillow).

# %%
from random import randint as rnd
from time import time
import importlib
import numpy1.functions as functions
import functions_vectorized
from numpy1.functions import convert_image as fpy
from functions_vectorized import convert_image  as fvec
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image 

importlib.reload(functions)
importlib.reload(functions_vectorized)

coefs = np.array([0.299, 0.587, 0.114])
img = np.array(Image.open("rayan_gosling.png"))

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(img)
axes[0].set_title('Original')
axes[0].axis('off')

img_conv = fvec(img, coefs)
axes[1].imshow(img_conv, cmap="gray")
axes[1].set_title('Converted')
axes[1].axis('off')

plt.show()

data_size = [x for x in range(1, 1500, 50)]
tvec = []
tpy = []

for n in data_size:
    x = np.random.randint(0, 256, size = (n, n, 3))
    st = time()
    fpy(x, coefs)
    tpy.append(time() - st)
    st = time()
    fvec(x, coefs)
    tvec.append(time() - st)

plt.figure(figsize=(8, 6))

plt.plot(data_size, tpy, label=u"Невекторизованная")
plt.plot(data_size, tvec, label=u"Векторизованная")

plt.title(u"Сравнение времени выполнения алгоритмов")
plt.xlabel(u"Размер данных")
plt.ylabel(u"Время (с)")
plt.grid(True)
plt.legend()

# %% [markdown]
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).

# %%
from random import randint as rnd
from time import time
import importlib
import numpy1.functions as functions
import functions_vectorized
from numpy1.functions import run_length_encoding as fpy
from functions_vectorized import run_length_encoding  as fvec
import numpy as np
import matplotlib.pyplot as plt

importlib.reload(functions)
importlib.reload(functions_vectorized)

data_size = [x for x in range(10 ** 4, 2 * 10 ** 6 + 1, 10 ** 4)]
tvec = []
tpy = []

for n in data_size:
    x = np.random.randint(0, 10, size=(n))
    st = time()
    res = fpy(x)
    tpy.append(time() - st)
    st = time()
    res1 = fvec(x)
    tvec.append(time() - st)
plt.figure(figsize=(8, 6))

plt.plot(data_size, tpy, label=u"Невекторизованная")
plt.plot(data_size, tvec, label=u"Векторизованная")

plt.title(u"Сравнение времени выполнения алгоритмов")
plt.xlabel(u"Размер данных")
plt.ylabel(u"Время (с)")
plt.grid(True)
plt.legend()

# %% [markdown]
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Дополнительно сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).

# %%
from random import randint as rnd
from time import time
import importlib
import numpy1.functions as functions
import functions_vectorized
from numpy1.functions import pairwise_distance as fpy
from functions_vectorized import pairwise_distance as fvec
import numpy as np
import matplotlib.pyplot as plt
import scipy

importlib.reload(functions)
importlib.reload(functions_vectorized)

data_size = [x for x in range(1, 10000, 500)]
tvec = []
tpy = []
tscp = []

for n in data_size:
    x = np.random.randint(-1000, 1001, size=(n, 5))
    y = np.random.randint(-1000, 1001, size=(n, 5))
    if n <2002:
        st = time()
        res = fpy(x, y)
        tpy.append(time() - st)
    st = time()
    res1 = fvec(x, y)
    tvec.append(time() - st)
    st = time()
    res2 = scipy.spatial.distance.cdist(x, y)
    tscp.append(time() - st)

plt.figure(figsize=(8, 6))

plt.plot(data_size[:5], tpy, label=u"Невекторизованная")
plt.plot(data_size, tvec, label=u"Векторизованная")
plt.plot(data_size, tscp, label=u"scipy")

plt.title(u"Сравнение времени выполнения алгоритмов")
plt.xlabel(u"Размер данных")
plt.ylabel(u"Время (с)")
plt.grid(True)
plt.legend()

# %% [markdown]
# ### Туториал по Markdown
#
# __(1 балл)__
#
# Напишите краткий (а в данной домашке ещё и почти бесмысленный) отчёт с использованием 4-5 различных вариантов разметки/выделения текста.

# %% [markdown]
# # Отчёт
# В ходе данной работы я реализовал решение шести задач двумя разными способами - с использованием библиотеки **numpy** и без её использования. Реализация с numpy ускоряет код с помощью _векторизации_, поэтому она работает в разы быстрее. Также я научился строить графики с помощью ```matplotlib.pyplot```. Чтобы научиться пользоваться возможностями библиотеки numpy, я обратился к ~~нейросетям~~ документации. Разберём различия между реализациями на примере первой задачи - нахождения произведения чисел на диагонали матрицы.
# | Размер данных | Время работы реализации с numpy | Время работы реализации без numpy |
# |-------------|-------------|-------------|
# | 5000     | 0.09489    | 0.87261    |
# | 10000    | 0.18095    | 1.72543    |
# | 15000    | 0.55503    | 2.61163    |
# | 20000    | 0.40721    | 3.41582    |
# | 25000    | 0.92434    | 4.36139    |
#
# Данная таблицы показывает время работы на некоторых размерах данных обоих реализаций. Она подтверждает наш вывод о том, что векторизация ускоряет код в несколько раз.
